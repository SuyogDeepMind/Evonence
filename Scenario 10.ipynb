# %%
Scenario 10: Summarization with Constraints
Task: Write a prompt to summarize a news article into 2 sentences. If the summary exceeds 50 words, truncate it to the nearest complete sentence.

# %%
Prompt: Summarize the following news article in exactly two sentences. Ensure the total summary does not exceed 50 words. If the summary exceeds 50 words, truncate it to the nearest complete sentence without adding new information.
